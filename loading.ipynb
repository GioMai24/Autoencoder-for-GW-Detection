# %%
import pickle
import matplotlib.pyplot as plt
import torch
import custom.models as mod

# %%
with open('../loss_50.pickle', 'rb') as f: losses = pickle.load(f)

# %%
modo = torch.load('../mod_opt_scal_150.pt', weights_only=True)

# %%
model = mod.LSTMAEUni()

# %%
fig, ax = plt.subplots(layout='constrained')
ax.plot(losses['train'], label='train')
ax.plot(losses['test'], label='test')
ax.legend()
plt.show()

# %% [markdown]
# # New training

# %%
import matplotlib.pyplot as plt
import pickle

with open('../losses_230.pickle', 'rb') as fin: losses = pickle.load(fin)

# %%
fig, ax = plt.subplots(layout='constrained')
ax.plot(losses['train'], label='train')
ax.plot(losses['val'], label='val')
# ax.set_xlim([150, 220])
# ax.set_ylim([0.005, .008])
ax.legend()
plt.show()
